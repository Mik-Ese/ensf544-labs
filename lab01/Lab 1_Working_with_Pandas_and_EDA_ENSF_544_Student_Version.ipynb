# %% [markdown]
# ### Pandas: Filtering the data:
#
# The dataset I will be using: [link](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview)
#
# Data Description: [link](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)

# %%
import pandas as pd
import numpy as np

# %%
# read the dataset
df = pd.read_csv('./content/house_prices_ex/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
# show all the columns for the first 10 rows
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 5         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 7         Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 8         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 9         Lvl    AllPub    Corner       Gtl      BrkSide     Artery
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
# 5       Norm     1Fam     1.5Fin            5            5       1993
# 6       Norm     1Fam     1Story            8            5       2004
# 7       Norm     1Fam     2Story            7            6       1973
# 8       Norm     1Fam     1.5Fin            7            5       1931
# 9     Artery   2fmCon     1.5Unf            5            6       1939
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 5          1995     Gable  CompShg     VinylSd     VinylSd        NaN
# 6          2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 7          1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 8          1950     Gable  CompShg     BrkFace     Wd Shng        NaN
# 9          1950     Gable  CompShg     MetalSd     MetalSd        NaN
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
# 5         0.0        TA        TA       Wood       Gd       TA           No
# 6       186.0        Gd        TA      PConc       Ex       TA           Av
# 7       240.0        TA        TA     CBlock       Gd       TA           Mn
# 8         0.0        TA        TA     BrkTil       TA       TA           No
# 9         0.0        TA        TA     BrkTil       TA       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
# 5          GLQ         732          Unf           0         64          796
# 6          GLQ        1369          Unf           0        317         1686
# 7          ALQ         859          BLQ          32        216         1107
# 8          Unf           0          Unf           0        952          952
# 9          GLQ         851          Unf           0        140          991
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
# 5    GasA        Ex          Y      SBrkr       796       566             0
# 6    GasA        Ex          Y      SBrkr      1694         0             0
# 7    GasA        Ex          Y      SBrkr      1107       983             0
# 8    GasA        Gd          Y      FuseF      1022       752             0
# 9    GasA        Ex          Y      SBrkr      1077         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
# 5       1362             1             0         1         1             1
# 6       1694             1             0         2         0             3
# 7       2090             1             0         2         1             3
# 8       1774             0             0         2         0             2
# 9       1077             1             0         1         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
# 5             1          TA             5        Typ           0         NaN
# 6             1          Gd             7        Typ           1          Gd
# 7             1          TA             7        Typ           2          TA
# 8             2          TA             8       Min1           2          TA
# 9             2          TA             5        Typ           2          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
# 5     Attchd       1993.0          Unf           2         480         TA
# 6     Attchd       2004.0          RFn           2         636         TA
# 7     Attchd       1973.0          RFn           2         484         TA
# 8     Detchd       1931.0          Unf           2         468         Fa
# 9     Attchd       1939.0          RFn           1         205         Gd
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
# 5         TA          Y          40           30              0        320
# 6         TA          Y         255           57              0          0
# 7         TA          Y         235          204            228          0
# 8         TA          Y          90            0            205          0
# 9         TA          Y           0            4              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2008
# 1            0         0    NaN    NaN         NaN        0       5    2007
# 2            0         0    NaN    NaN         NaN        0       9    2008
# 3            0         0    NaN    NaN         NaN        0       2    2006
# 4            0         0    NaN    NaN         NaN        0      12    2008
# 5            0         0    NaN  MnPrv        Shed      700      10    2009
# 6            0         0    NaN    NaN         NaN        0       8    2007
# 7            0         0    NaN    NaN        Shed      350      11    2009
# 8            0         0    NaN    NaN         NaN        0       4    2008
# 9            0         0    NaN    NaN         NaN        0       1    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000
# 5       WD        Normal     143000
# 6       WD        Normal     307000
# 7       WD        Normal     200000
# 8       WD       Abnorml     129900
# 9       WD        Normal     118000

# %%
# are there any duplicated rows?
df.duplicated().sum()
# Out:
# 0

# %%
# do we have any duplicates in Neighborhood?
df.duplicated(subset=['Neighborhood']).sum()
# Out:
# 1435

# %%
# remove duplicates in Neighborhood by keeping only the first record for each
# Neighborhood and view the new dataset
# do not over-write the dataframe
df.drop_duplicates(subset=['Neighborhood'], keep='first').Neighborhood
# Out:
# 0      CollgCr
# 1      Veenker
# 3      Crawfor
# 4      NoRidge
# 5      Mitchel
# 6      Somerst
# 7       NWAmes
# 8      OldTown
# 9      BrkSide
# 10      Sawyer
# 11     NridgHt
# 14       NAmes
# 18     SawyerW
# 21      IDOTRR
# 23     MeadowV
# 39     Edwards
# 41      Timber
# 50     Gilbert
# 58     StoneBr
# 69     ClearCr
# 126    NPkVill
# 219    Blmngtn
# 225     BrDale
# 267      SWISU
# 599    Blueste
# Name: Neighborhood, dtype: object

# %%
# How many listings do we have?
len(df)
# Out:
# 1460

# %%
# How many columns do we have?
len(df.columns)
# Out:
# 81

# %%
# use .shape to see the column and rows length
print("The data size is : {} ".format(df.shape))
# Out:
# The data size is : (1460, 81)

# %%
# take a look at the datatypes (object datatype means: strings, lists, or other non-numeric types)
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# Heating           object
# HeatingQC         object
# CentralAir        object
# Electrical        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# dtype: object

# %%
# get some stats in
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
# describe only the SalePrice
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Convert 'YearBuilt' type to int
df['YearBuilt'] = pd.to_numeric(df['YearBuilt'], errors='coerce')

# %%
# which are the oldest houses?
df.sort_values('YearBuilt').head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1137  1138          50       RL         54.0     6342   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1137         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1349       Norm     1Fam     2Story            8            5       1872
# 1137       Norm     1Fam     1.5Fin            5            8       1875
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1349          1987     Gable  CompShg     MetalSd     MetalSd        NaN
# 1137          1996     Gable  CompShg     VinylSd     VinylSd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 1137         0.0        TA        Gd     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1349           No          LwQ         259          Unf           0
# 1137           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1349        425          684    OthW        Fa          N      SBrkr
# 1137        780          780    GasA        Gd          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1349       938      1215           205       2358             0             0
# 1137       780       240             0       1020             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1349         2         0             4             1          TA
# 1137         1         0             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1349             8        Typ           0         NaN        NaN          NaN
# 1137             6        Typ           0         NaN        NaN          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1349          NaN           0           0        NaN        NaN          Y
# 1137          NaN           0           0        NaN        NaN          N
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1349           0           54             20          0            0
# 1137           0            0            176          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1349         0    NaN   NaN         NaN        0      12    2008       WD
# 1137         0    NaN   NaN         NaN        0       5    2010       WD
#
#      SaleCondition  SalePrice
# 1349        Normal     122000
# 1137        Normal      94000

# %%
# take a look at only one neighborhood (NoRidge)
df[df.Neighborhood == 'NoRidge']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 85      86          60       RL        121.0    16059   Pave   NaN      Reg
# 226    227          60       RL         82.0     9950   Pave   NaN      IR1
# 231    232          60       RL        174.0    15138   Pave   NaN      IR1
# 272    273          60       RL         92.0    11764   Pave   NaN      IR1
# 318    319          60       RL         90.0     9900   Pave   NaN      Reg
# 359    360          60       RL         78.0    12011   Pave   NaN      IR1
# 403    404          60       RL         93.0    12090   Pave   NaN      Reg
# 654        Norm     1Fam     1Story            8            6       1995
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 691        Norm     1Fam     2Story           10            6       1994
# 718        Norm     1Fam     2Story            7            5       1993
# 748        Norm     1Fam     1Story            7            5       1996
# 759        Norm     1Fam     2Story            8            5       1995
# 763        Norm     1Fam     2Story            8            5       1999
# 792        Norm     1Fam     2Story            7            5       1996
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1032       Norm     1Fam     2Story            8            7       1993
# 1057       Norm     1Fam     2Story            7            6       1994
# 1105       Norm     1Fam     2Story            8            5       1994
# 1169       Norm     1Fam     2Story           10            5       1995
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1182       Norm     1Fam     2Story           10            5       1996
# 1187       Norm     1Fam     1Story            8            5       1994
# 1256       Norm     1Fam     1Story            8            5       1994
# 1302       Norm     1Fam     2Story            8            5       1994
# 1312       Norm     1Fam     2Story            8            5       1990
# 1313       Norm     1Fam     2Story            9            5       1999
# 1322       Norm     1Fam     2Story            7            5       1992
# 1353       Norm     1Fam     1.5Fin            8            5       1995
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
# 1426       Norm     1Fam     2Story            7            5       1994
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 85            1992       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 226           1995     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 231           1996     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 318           1993     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 496           1993       Hip  CompShg     BrkFace     BrkFace        NaN
# 517           1997     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 524           1997     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard        NaN
# 654           1995       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 691           1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
# 718           1994       Hip  CompShg     Wd Sdng     ImStucc    BrkFace
# 748           1996       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 759           1995     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 792           1997     Gable  CompShg     MetalSd     MetalSd        NaN
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1032          1993     Gable  CompShg     MetalSd     MetalSd        NaN
# 1057          1994     Gable  CompShg     HdBoard     HdBoard        NaN
# 1105          1995     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1169          1996       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc        NaN
# 1187          1995     Gable  CompShg     ImStucc     ImStucc        NaN
# 1256          1994       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1302          1994       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1312          1990     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1322          1992     Gable  CompShg     HdBoard     HdBoard        NaN
# 1353          1996       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1426          1994     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 85         284.0        Gd        TA     CBlock       Gd       TA
# 226        290.0        Gd        TA      PConc       Gd       TA
# 231        506.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 318        256.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 496          0.0        Gd        TA      PConc       Gd       TA
# 517        921.0        Gd        TA      PConc       Gd       TA
# 524        594.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 654        660.0        Gd        Gd      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 691       1170.0        Ex        TA      PConc       Ex       TA
# 718        651.0        Gd        TA      PConc       Gd       TA
# 748        338.0        Gd        TA      PConc       Gd       TA
# 759        513.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 792          0.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1032         0.0        Gd        Gd      PConc       Gd       Gd
# 1057         0.0        Gd        TA      PConc       Gd       TA
# 1105       362.0        Gd        TA      PConc       Ex       TA
# 1169      1378.0        Gd        Gd      PConc       Ex       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1182         0.0        Gd        TA      PConc       Ex       TA
# 1187         0.0        Gd        TA      PConc       Gd       TA
# 1256       554.0        Gd        TA      PConc       Gd       TA
# 1302       391.0        Gd        TA      PConc       Gd       TA
# 1312       336.0        Gd        TA      PConc       Ex       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1322         0.0        Gd        TA      PConc       Gd       TA
# 1353       579.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
# 1426       448.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 4              Av          GLQ         655          Unf           0
# 85             No          Unf           0          Unf           0
# 226            No          GLQ         565          Unf           0
# 231            No          GLQ         689          Unf           0
# 272            No          GLQ         524          Unf           0
# 318            Gd          GLQ         987          Unf           0
# 359            Av          GLQ         956          Unf           0
# 403            No          Unf           0          Unf           0
# 423            No          GLQ         986          Unf           0
# 496            No          GLQ        1231          Unf           0
# 517            No          Unf           0          Unf           0
# 524            No          GLQ         719          Unf           0
# 541            No          Unf           0          Unf           0
# 564            No          GLQ         728          Unf           0
# 654            Gd          GLQ        1696          Unf           0
# 661            No          GLQ        1361          Rec         180
# 684            No          Unf           0          Unf           0
# 691            Gd          GLQ        1455          Unf           0
# 718            Gd          GLQ        1173          Unf           0
# 748            No          GLQ         919          Unf           0
# 759            Av          LwQ          56          ALQ          64
# 763            Mn          GLQ        1163          Unf           0
# 792            Av          GLQ         862          Unf           0
# 981            No          GLQ         854          Unf           0
# 990            No          GLQ        1074          Unf           0
# 1032           No          GLQ        1012          Unf           0
# 1057           No          GLQ         595          Unf           0
# 1105           Av          GLQ        1032          Unf           0
# 1169           Gd          GLQ        1387          Unf           0
# 1175           No          GLQ         700          Unf           0
# 1182           Av          GLQ        2096          Unf           0
# 1187           No          GLQ        1456          Unf           0
# 1256           Gd          GLQ        1314          Unf           0
# 1302           No          GLQ         740          Unf           0
# 1312           No          GLQ         482          Unf           0
# 1313           No          Unf           0          Unf           0
# 1322           No          GLQ         674          Unf           0
# 1353           Av          GLQ         816          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1417           Mn          GLQ         781          Unf           0
# 1426           No          GLQ        1000          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
#
# 748              7        Typ           1          TA     Attchd       1996.0
# 759              9        Typ           1          TA     Attchd       1995.0
# 763              8        Typ           1          Gd     Attchd       1999.0
# 792              8        Typ           1          TA     Attchd       1997.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1032            10        Typ           1          TA     Attchd       1993.0
# 1057             7        Typ           1          Gd    BuiltIn       1994.0
# 1105             9        Typ           2          TA     Attchd       1994.0
# 1169            10        Typ           1          TA     Attchd       1995.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1182            10        Typ           2          TA     Attchd       1996.0
# 1187             5        Typ           1          Fa     Attchd       1994.0
# 1256             7        Typ           1          TA     Attchd       1994.0
# 1302             8        Typ           1          TA     Attchd       1994.0
# 1312             9        Typ           1          Ex     Attchd       1990.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1322             8        Typ           1          TA     Attchd       1992.0
# 1353             9        Typ           1          Ex     Attchd       1996.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
# 1426             5        Typ           2          TA     Attchd       1994.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 85            Unf           2         462         TA         TA          Y
# 226           RFn           3         721         TA         TA          Y
# 231           Fin           3         810         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 318           RFn           3         656         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 496           RFn           2         546         TA         TA          Y
# 517           RFn           3         889         TA         TA          Y
# 524           Fin           3         834         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 654           Fin           3         839         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 691           Fin           3         832         TA         TA          Y
# 718           RFn           3         983         TA         TA          Y
# 748           Fin           2         527         TA         TA          Y
# 759           RFn           3         752         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 792           Unf           2         455         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1032          RFn           3         796         TA         TA          Y
# 1057          Fin           2         467         TA         TA          Y
# 1105          RFn           2         712         TA         TA          Y
# 1169          Fin           3         807         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1182          Fin           3         813         TA         TA          Y
# 1187          RFn           3         757         TA         TA          Y
# 1256          Fin           2         691         TA         TA          Y
# 1302          RFn           3         844         TA         TA          Y
# 1312          RFn           2         750         Gd         Gd          Y
# 1313          Fin           3         779         TA         TA          Y
# 1322          RFn           2         564         TA         TA          Y
# 1353          Fin           3         666         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
# 1426          RFn           2         525         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 85           127           82              0          0            0
# 226          224          114              0          0            0
# 231            0          146            202          0            0
# 272          132           57              0          0            0
# 318          340           60            144          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 496          264           75            291          0            0
# 517          220            0              0          0            0
# 524          239           60              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 654          236           46              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 691          382           50              0          0            0
# 718          250          154            216          0            0
# 748          240           56            154          0            0
# 759          222           98              0          0            0
# 763            0          128              0          0          180
# 792          180          130              0          0            0
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1032         209           55              0          0            0
# 1057         168           98              0          0            0
# 1105         186           32              0          0            0
# 1169         361           76              0          0            0
# 1175           0           33              0          0            0
# 1182         171           78              0          0            0
# 1187           0          114            192          0            0
# 1256         262           36              0          0            0
# 1302         309           78              0          0            0
# 1312         500            0              0          0            0
# 1313         668           30              0          0            0
# 1322         240           39              0          0            0
# 1353         283           86              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
# 1426         171          132              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# 85           0    NaN    NaN         NaN        0       4    2006       WD
# 226          0    NaN    NaN         NaN        0       6    2007       WD
# 231          0    NaN    NaN         NaN        0       7    2009       WD
# 272          0    NaN    NaN         NaN        0       4    2010       WD
# 318          0    NaN    NaN         NaN        0       4    2009       WD
# 359          0    NaN    NaN         NaN        0       6    2006       WD
# 403          0    NaN    NaN         NaN        0       7    2006       WD
# 423          0    NaN    NaN         NaN        0       6    2008       WD
# 496          0    NaN    NaN         NaN        0       5    2007       WD
# 517          0    NaN    NaN         NaN        0       7    2009       WD
# 524          0    NaN    NaN         NaN        0       8    2007       WD
# 541          0    NaN    NaN         NaN        0       6    2007       WD
# 564          0    NaN    NaN         NaN        0       7    2006       WD
# 654          0    NaN    NaN         NaN        0       8    2008       WD
# 661          0    NaN    NaN         NaN        0       7    2009       WD
# 684          0    NaN    NaN         NaN        0       6    2010       WD
# 691          0    NaN    NaN         NaN        0       1    2007       WD
# 718          0    NaN    NaN         NaN        0       8    2008       WD
# 748          0    NaN    NaN         NaN        0       3    2010       WD
# 759          0    NaN    NaN         NaN        0      11    2007       WD
# 763          0    NaN    NaN         NaN        0       7    2009       WD
# 792          0    NaN    NaN         NaN        0       6    2007       WD
# 981          0    NaN    NaN         NaN        0       7    2009       WD
# 990          0    NaN    NaN         NaN        0       6    2006       WD
# 1032         0    NaN    NaN         NaN        0      11    2006       WD
# 1057         0    NaN    NaN         NaN        0       1    2009       WD
# 1105         0    NaN    NaN         NaN        0       4    2010       WD
# 1169         0    NaN    NaN         NaN        0       7    2006       WD
# 1175         0    NaN    NaN         NaN        0       4    2007       WD
# 1182       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1187         0    NaN  GdPrv         NaN        0       7    2006       WD
# 1256         0    NaN    NaN         NaN        0       8    2008       WD
# 1302         0    NaN    NaN         NaN        0      12    2006       WD
# 1312         0    NaN    NaN         NaN        0       6    2007       WD
# 1313         0    NaN    NaN         NaN        0       5    2010       WD
# 1322         0    NaN    NaN         NaN        0       6    2010       WD
# 1353         0    NaN    NaN         NaN        0       3    2010       WD
# 1373         0    NaN    NaN         NaN        0       3    2007       WD
# 1417         0    NaN    NaN         NaN        0       5    2009       WD
# 1426         0    NaN    NaN         NaN        0       8    2008       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 85          Normal     260000
# 226        Abnorml     290000
# 231         Normal     403000
# 272         Normal     290000
# 318         Normal     260000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 496         Normal     430000
# 517         Normal     265000
# 524         Normal     315750
# 541         Normal     248000
# 564         Normal     268000
# 654         Normal     350000
# 661         Normal     402000
# 684         Normal     221000
# 691         Normal     755000
# 718         Normal     341000
# 748         Normal     260400
# 759         Normal     290000
# 763         Normal     337000
# 792         Normal     269790
# 981         Normal     336000
# 990         Normal     348000
# 1032       Abnorml     310000
# 1057        Normal     248000
# 1105        Normal     325000
# 1169        Normal     625000
# 1175        Normal     285000
# 1182       Abnorml     745000
# 1187        Normal     262000
# 1256        Normal     301500
# 1302        Normal     290000
# 1312        Normal     302000
# 1313        Normal     333168
# 1322        Normal     190000
# 1353        Normal     410000
# 1373        Normal     466500
# 1417        Normal     340000
# 1426        Normal     271000

# %%
# how many houses are there in this neighborhood?
len(df[df.Neighborhood == 'NoRidge'])
# Out:
# 41

# %%
# first 2 houses that were built in NoRidge neighborhood
df[df.Neighborhood == 'NoRidge'].sort_values('YearBuilt').head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1312  1313          60       RL          NaN     9572   Pave   NaN      IR1
# 85      86          60       RL        121.0    16059   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1312         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 85           Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1312       Norm     1Fam     2Story            8            5       1990
# 85         Norm     1Fam     2Story            8            5       1991
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1312          1990     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 85            1992       Hip  CompShg     HdBoard     HdBoard    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1312       336.0        Gd        TA      PConc       Ex       TA
# 85         284.0        Gd        TA     CBlock       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1312           No          GLQ         482          Unf           0
# 85             No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1312        971         1453    GasA        Ex          Y      SBrkr
# 85         1288         1288    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1312      1453      1357             0       2810             0             0
# 85        1301      1116             0       2417             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1312         2         1             4             1          Gd
# 85           2         1             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1312             9        Typ           1          Ex     Attchd       1990.0
# 85               9        Typ           1          TA     Attchd       1991.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1312          RFn           2         750         Gd         Gd          Y
# 85            Unf           2         462         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1312         500            0              0          0            0
# 85           127           82              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1312         0    NaN   NaN         NaN        0       6    2007       WD
# 85           0    NaN   NaN         NaN        0       4    2006       WD
#
#      SaleCondition  SalePrice
# 1312        Normal     302000
# 85          Normal     260000

# %%
# last 2 houses that was built in NoRidge neighborhood
df[df.Neighborhood == 'NoRidge'].sort_values('YearBuilt', ascending=False).head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1373       Norm     1Fam     1Story           10            5       2001
# 4          Norm     1Fam     2Story            8            5       2000
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 4          350.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1373           Gd          GLQ        1282          Unf           0
# 4              Av          GLQ         655          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1373      2633         0             0       2633             1             0
# 4         1145      1053             0       2198             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1373         2         1             2             1          Ex
# 4            2         1             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 4                9        Typ           1          TA     Attchd       2000.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1373          RFn           3         804         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1373         314          140              0          0            0
# 4            192           84              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 4            0    NaN   NaN         NaN        0      12    2008       WD
#
#      SaleCondition  SalePrice
# 1373        Normal     466500
# 4           Normal     250000

# %%
# Let's take a look at the NoRidge neighborhood for houses that
# were remodelled after or in 1998
df_noridge = df[df.Neighborhood == 'NoRidge']
df_noridge[df_noridge.YearRemodAdd >= 1998]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 272    273          60       RL         92.0    11764   Pave   NaN      IR1
# 359    360          60       RL         78.0    12011   Pave   NaN      IR1
# 403    404          60       RL         93.0    12090   Pave   NaN      Reg
# 423    424          60       RL         80.0     9200   Pave   NaN      Reg
# 541    542          60       RL          NaN    11000   Pave   NaN      Reg
# 564    565          60       RL          NaN    13346   Pave   NaN      IR1
# 661    662          60       RL         52.0    46589   Pave   NaN      IR2
# 684    685          60       RL         58.0    16770   Pave   NaN      IR2
# 763    764          60       RL         82.0     9430   Pave   NaN      Reg
# 981    982          60       RL         98.0    12203   Pave   NaN      IR1
# 990    991          60       RL         82.0     9452   Pave   NaN      Reg
# 1175  1176          50       RL         85.0    10678   Pave   NaN      Reg
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 272          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 359          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 403          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 423          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 541          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 564          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 661          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 684          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 763          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 981          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 990          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1175         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1313         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1417         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 4          Norm     1Fam     2Story            8            5       2000
# 272        Norm     1Fam     2Story            8            7       1999
# 359        Norm     1Fam     2Story            8            5       1998
# 403        Norm     1Fam     2Story            8            5       1998
# 423        Norm     1Fam     2Story            8            5       1998
# 541        Norm     1Fam     2Story            8            5       2000
# 564        Norm     1Fam     2Story            7            5       1992
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 763        Norm     1Fam     2Story            8            5       1999
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1313       Norm     1Fam     2Story            9            5       1999
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard        NaN
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
#
2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 4                9        Typ           1          TA     Attchd       2000.0
# 272              9        Typ           1          Gd     Attchd       1999.0
# 359              7        Typ           1          TA     Attchd       1998.0
# 403             10        Typ           1          TA    BuiltIn       1998.0
# 423              8        Typ           1          TA     Attchd       1998.0
# 541              8        Typ           1          TA    BuiltIn       2000.0
# 564              9        Typ           1          TA     Attchd       1992.0
# 661              8        Typ           1          TA     Attchd       1994.0
# 684              7        Typ           0         NaN     Attchd       1998.0
# 763              8        Typ           1          Gd     Attchd       1999.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1313          Fin           3         779         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 272          132           57              0          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 763            0          128              0          0          180
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1175           0           33              0          0            0
# 1313         668           30              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN   NaN         NaN        0      12    2008       WD
# 272          0    NaN   NaN         NaN        0       4    2010       WD
# 359          0    NaN   NaN         NaN        0       6    2006       WD
# 403          0    NaN   NaN         NaN        0       7    2006       WD
# 423          0    NaN   NaN         NaN        0       6    2008       WD
# 541          0    NaN   NaN         NaN        0       6    2007       WD
# 564          0    NaN   NaN         NaN        0       7    2006       WD
# 661          0    NaN   NaN         NaN        0       7    2009       WD
# 684          0    NaN   NaN         NaN        0       6    2010       WD
# 763          0    NaN   NaN         NaN        0       7    2009       WD
# 981          0    NaN   NaN         NaN        0       7    2009       WD
# 990          0    NaN   NaN         NaN        0       6    2006       WD
# 1175         0    NaN   NaN         NaN        0       4    2007       WD
# 1313         0    NaN   NaN         NaN        0       5    2010       WD
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 1417         0    NaN   NaN         NaN        0       5    2009       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 272         Normal     290000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 541         Normal     248000
# 564         Normal     268000
# 661         Normal     402000
# 684         Normal     221000
# 763         Normal     337000
# 981         Normal     336000
# 990         Normal     348000
# 1175        Normal     285000
# 1313        Normal     333168
# 1373        Normal     466500
# 1417        Normal     340000

# %%
# another way of doing this?
df[(df.Neighborhood == 'NoRidge') & (df.YearRemodAdd >= 1998)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 272    273          60       RL         92.0    11764   Pave   NaN      IR1
# 359    360          60       RL         78.0    12011   Pave   NaN      IR1
# 403    404          60       RL         93.0    12090   Pave   NaN      Reg
# 423    424          60       RL         80.0     9200   Pave   NaN      Reg
# 541    542          60       RL          NaN    11000   Pave   NaN      Reg
# 564    565          60       RL          NaN    13346   Pave   NaN      IR1
# 661    662          60       RL         52.0    46589   Pave   NaN      IR2
# 684    685          60       RL         58.0    16770   Pave   NaN      IR2
# 763    764          60       RL         82.0     9430   Pave   NaN      Reg
# 981    982          60       RL         98.0    12203   Pave   NaN      IR1
# 990    991          60       RL         82.0     9452   Pave   NaN      Reg
# 1175  1176          50       RL         85.0    10678   Pave   NaN      Reg
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 272          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 359          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 403          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 423          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 541          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 564          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 661          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 684          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 763          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 981          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 990          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1175         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1313         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1417         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 4          Norm     1Fam     2Story            8            5       2000
# 272        Norm     1Fam     2Story            8            7       1999
# 359        Norm     1Fam     2Story            8            5       1998
# 403        Norm     1Fam     2Story            8            5       1998
# 423        Norm     1Fam     2Story            8            5       1998
# 541        Norm     1Fam     2Story            8            5       2000
# 564        Norm     1Fam     2Story            7            5       1992
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 763        Norm     1Fam     2Story            8            5       1999
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1313       Norm     1Fam     2Story            9            5       1999
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard        NaN
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 4              Av          GLQ         655          Unf           0
# 272            No          GLQ         524          Unf           0
# 359            Av          GLQ         956          Unf           0
# 403            No          Unf           0          Unf           0
# 423            No          GLQ         986          Unf           0
# 541            No          Unf           0          Unf           0
# 564            No          GLQ         728          Unf           0
# 661            No          GLQ        1361          Rec         180
# 684            No          Unf           0          Unf           0
# 763            Mn          GLQ        1163          Unf           0
# 981            No          GLQ         854          Unf           0
# 990            No          GLQ        1074          Unf           0
# 1175           No          GLQ         700          Unf           0
# 1313           No          Unf           0          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1417           Mn          GLQ         781          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 4           490         1145    GasA        Ex          Y      SBrkr
# 272         628         1152    GasA        Ex          Y      SBrkr
# 359         130         1086    GasA        Ex          Y      SBrkr
# 403        1141         1141    GasA        Gd          Y      SBrkr
# 423         484         1470    GasA        Gd          Y      SBrkr
# 541         969          969    GasA        Ex          Y      SBrkr
# 564         367         1095    GasA        Ex          Y      SBrkr
# 661          88         1629    GasA        Ex          Y      SBrkr
# 684        1195         1195    GasA        Gd          Y      SBrkr
# 763          89         1252    GasA        Ex          Y      SBrkr
# 981         371         1225    GasA        Ex          Y      SBrkr
# 990         322         1396    GasA        Ex          Y      SBrkr
# 1175        983         1683    GasA        Ex          Y      SBrkr
# 1313       1393         1393    GasA        Ex          Y      SBrkr
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 1417        503         1284    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 4         1145      1053             0       2198             1             0
# 272       1164      1106             0       2270             0             0
# 359       1086       838             0       1924             1             0
# 403       1165      1098             0       2263             0             0
# 423       1470      1160             0       2630             1             0
# 541        997      1288             0       2285             0             0
# 564       1166      1129             0       2295             1             0
# 661       1686       762             0       2448             1             0
# 684       1195       644             0       1839             0             0
# 763       1268      1097             0       2365             1             0
# 981       1276      1336             0       2612             1             0
# 990       1407       985             0       2392             1             0
# 1175      2129       743             0       2872             0             0
# 1313      1422      1177             0       2599             0             0
# 1373      2633         0             0       2633             1             0
# 1417      1310      1140             0       2450             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 4            2         1             4             1          Gd
# 272          2         1             4             1          Gd
# 359          2         1             3             1          Gd
# 403          2         1             4             1          Gd
# 423          2         1             4             1          Gd
# 541          2         1             4             1          Gd
# 564          2         1             4             1          Gd
# 661          2         1             4             1          Gd
# 684          2         1             4             1          TA
# 763          2         1             3             1          Gd
# 981          2         1             4             1          Gd
# 990          2         1             3             1          Gd
# 1175         2         1             4             1          Gd
# 1313         2         1             4             1          Gd
# 1373         2         1             2             1          Ex
# 1417         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 4                9        Typ           1          TA     Attchd       2000.0
# 272              9        Typ           1          Gd     Attchd       1999.0
# 359              7        Typ           1          TA     Attchd       1998.0
# 403             10        Typ           1          TA    BuiltIn       1998.0
# 423              8        Typ           1          TA     Attchd       1998.0
# 541              8        Typ           1          TA    BuiltIn       2000.0
# 564              9        Typ           1          TA     Attchd       1992.0
# 661              8        Typ           1          TA     Attchd       1994.0
# 684              7        Typ           0         NaN     Attchd       1998.0
# 763              8        Typ           1          Gd     Attchd       1999.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1313          Fin           3         779         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 272          132           57              0          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 763            0          128              0          0          180
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1175           0           33              0          0            0
# 1313         668           30              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN   NaN         NaN        0      12    2008       WD
# 272          0    NaN   NaN         NaN        0       4    2010       WD
# 359          0    NaN   NaN         NaN        0       6    2006       WD
# 403          0    NaN   NaN         NaN        0       7    2006       WD
# 423          0    NaN   NaN         NaN        0       6    2008       WD
# 541          0    NaN   NaN         NaN        0       6    2007       WD
# 564          0    NaN   NaN         NaN        0       7    2006       WD
# 661          0    NaN   NaN         NaN        0       7    2009       WD
# 684          0    NaN   NaN         NaN        0       6    2010       WD
# 763          0    NaN   NaN         NaN        0       7    2009       WD
# 981          0    NaN   NaN         NaN        0       7    2009       WD
# 990          0    NaN   NaN         NaN        0       6    2006       WD
# 1175         0    NaN   NaN         NaN        0       4    2007       WD
# 1313         0    NaN   NaN         NaN        0       5    2010       WD
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 1417         0    NaN   NaN         NaN        0       5    2009       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 272         Normal     290000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 541         Normal     248000
# 564         Normal     268000
# 661         Normal     402000
# 684         Normal     221000
# 763         Normal     337000
# 981         Normal     336000
# 990         Normal     348000
# 1175        Normal     285000
# 1313        Normal     333168
# 1373        Normal     466500
# 1417        Normal     340000

# %%
# How many houses were built from 1950 through 1959?
len(df[(df.YearBuilt >= 1950) & (df.YearBuilt <= 1959)])
# Out:
# 167

# %%
# another way of doing this?
len(df[df.YearBuilt // 10 == 195])
# Out:
# 167

# %%
# how many fireplaces can a house have?
df.Fireplaces.unique()
# Out:
# array([0, 1, 2, 3])

# %%
# how many types of kitchen quality do we have?
df.KitchenQual.unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
# how many types of heating do we have?
df.Heating.unique()
# Out:
# array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW', 'Floor'], dtype=object)

# %%
# how to view only houses that are heated by gas?
df[df.Heating.str.contains('Gas')].Heating
# Out:
# 0       GasA
# 1       GasA
# 2       GasA
# 3       GasA
# 4       GasA
# 5       GasA
# 6       GasA
# 7       GasA
# 8       GasA
# 9       GasA
# 10      GasA
# 11      GasA
# 12      GasA
# 13      GasA
# 14      GasA
# 15      GasA
# 16      GasA
# 17      GasA
# 18      GasA
# 19      GasA
# 20      GasA
# 21      GasA
# 22      GasA
# 23      GasA
# 24      GasA
# 25      GasA
# 26      GasA
# 27      GasA
# 28      GasA
# 29      GasA
# 30      GasA
# 31      GasA
# 32      GasA
# 33      GasA
# 34      GasA
# 35      GasA
# 36      GasA
# 37      GasA
# 38      GasA
# 39      GasA
# 40      GasA
# 41      GasA
# 42      GasA
# 43      GasA
# 44      GasA
# 45      GasA
# 46      GasA
# 47      GasA
# 48      GasA
# 49      GasA
# 50      GasA
# 51      GasA
# 52      GasA
# 53      GasA
# 54      GasA
# 55      GasA
# 56      GasA
# 57      GasA
# 58      GasA
# 59      GasA
# 60      GasA
# 61      GasA
# 62      GasA
# 63      GasA
# 64      GasA
# 65      GasA
# 66      GasA
# 67      GasA
# 68      GasA
# 69      GasW
# 70      GasA
# 71      GasA
# 72      GasA
# 73      GasA
# 74      GasA
# 75      GasA
# 76      GasA
# 77      GasA
# 78      GasA
# 79      GasA
# 80      GasA
# 81      GasA
# 82      GasA
# 83      GasA
# 84      GasA
# 85      GasA
# 86      GasA
# 87      GasA
# 88      GasA
# 89      GasA
# 90      GasA
# 91      GasA
# 92      GasA
# 93      GasW
# 94      GasA
# 95      GasA
# 96      GasA
# 97      GasA
# 98      GasA
# 99      GasA
# 100     GasA
# 101     GasA
# 102     GasA
# 103     GasA
# 104     GasA
# 105     GasA
# 106     GasA
# 107     GasA
# 108     GasW
# 109     GasA
# 110     GasA
# 111     GasA
# 112     GasA
# 113     GasA
# 114     GasA
# 115     GasA
# 116     GasA
# 117     GasA
# 118     GasA
# 119     GasA
# 120     GasA
# 121     GasA
# 122     GasA
# 123     GasA
# 124     GasA
# 125     GasA
# 126     GasA
# 127     GasA
# 128     GasA
# 129     GasA
# 130     GasA
# 131     GasA
# 132     GasA
# 133     GasA
# 134     GasA
# 135     GasA
# 136     GasA
# 137     GasA
# 138     GasA
# 139     GasA
# 140     GasA
# 141     GasA
# 142     GasA
# 143     GasA
# 144     GasA
# 145     GasA
# 146     GasA
# 147     GasA
# 148     GasA
# 149     GasA
# 150     GasA
# 151     GasA
# 152     GasA
# 153     GasA
# 154     GasA
# 156     GasA
# 157     GasA
# 158     GasA
# 159     GasA
# 160     GasA
# 161     GasA
# 162     GasA
# 163     GasA
# 164     GasA
# 165     GasA
# 166     GasA
# 167     GasA
# 168     GasA
# 169     GasA
# 170     GasA
# 171     GasA
# 172     GasA
# 173     GasA
# 174     GasA
# 175     GasA
# 176     GasA
# 177     GasA
# 178     GasA
# 179     GasA
# 180     GasA
# 181     GasA
# 182     GasA
# 183     GasA
# 184     GasA
# 185     GasA
# 186     GasA
# 187     GasA
# 188     GasA
# 189     GasA
# 190     GasA
# 191     GasA
# 192     GasA
# 193     GasA
# 194     GasA
# 195     GasA
# 196     GasA
# 197     GasA
# 198     GasA
# 199     GasA
# 200     GasA
# 201     GasA
# 202     GasA
# 203     GasA
# 204     GasA
# 205     GasA
# 206     GasA
# 207     GasA
# 208     GasA
# 209     GasA
# 210     GasA
# 211     GasA
# 212     GasA
# 213     GasA
# 214     GasA
# 215     GasA
# 216     GasA
# 217     GasA
# 218     GasA
# 219     GasA
# 220     GasA
# 221     GasA
# 222     GasA
# 223     GasA
# 224     GasA
# 225     GasA
# 226     GasA
# 227     GasA
# 228     GasA
# 229     GasA
# 230     GasA
# 231     GasA
# 232     GasA
# 233     GasA
# 234     GasA
# 235     GasA
# 236     GasA
# 237     GasA
# 238     GasA
# 239     GasA
# 240     GasA
# 241     GasA
# 242     GasA
# 243     GasA
# 244     GasA
# 245     GasA
# 246     GasA
# 247     GasA
# 248     GasA
# 249     GasA
# 250     GasA
# 251     GasA
# 252     GasA
# 253     GasA
# 254     GasA
# 255     GasA
# 256     GasA
# 257     GasA
# 258     GasA
# 259     GasA
# 260     GasA
# 261     GasA
# 262     GasA
# 263     GasA
# 264     GasA
# 265     GasA
# 266     GasA
# 267     GasA
# 268     GasA
# 269     GasA
# 270     GasA
# 271     GasA
# 272     GasA
# 273     GasA
# 274     GasA
# 275     GasW
# 276     GasA
# 277     GasA
# 278     GasA
# 279     GasA
# 280     GasA
# 281     GasA
# 282     GasA
# 283     GasA
# 284     GasA
# 285     GasA
# 286     GasA
# 287     GasA
# 288     GasA
# 289     GasA
# 290     GasA
# 291     GasA
# 292     GasA
# 293     GasA
# 294     GasA
# 295     GasA
# 296     GasA
# 297     GasA
# 298     GasA
# 299     GasA
# 300     GasA
# 301     GasA
# 302     GasA
# 303     GasA
# 304     GasA
# 305     GasA
# 306     GasA
# 307     GasA
# 308     GasA
# 309     GasA
# 310     GasA
# 311     GasA
# 312     GasA
# 313     GasW
# 314     GasA
# 315     GasA
# 316     GasA
# 317     GasA
# 318     GasA
# 319     GasA
# 320     GasA
# 321     GasA
# 322     GasA
# 323     GasA
# 324     GasA
# 325     GasA
# 326     GasA
# 327     GasA
# 328     GasA
# 329     GasA
# 330     GasA
# 331     GasA
# 332     GasA
# 333     GasA
# 334     GasA
# 335     GasA
# 336     GasA
# 337     GasA
# 338     GasA
# 339     GasA
# 340     GasA
# 341     GasA
# 343     GasA
# 344     GasA
# 345     GasA
# 346     GasA
# 347     GasA
# 348     GasA
# 349     GasA
# 350     GasA
# 351     GasA
# 352     GasA
# 353     GasA
# 354     GasA
# 355     GasA
# 356     GasA
# 357     GasA
# 358     GasA
# 359     GasA
# 360     GasA
# 361     GasA
# 362     GasA
# 363     GasA
# 364     GasA
# 365     GasA
# 366     GasA
# 367     GasA
# 368     GasA
# 369     GasA
# 370     GasA
# 371     GasA
# 372     GasA
# 373     GasA
# 374     GasA
# 375     GasA
# 376     GasA
# 377     GasA
# 378     GasA
# 379     GasA
# 380     GasA
# 381     GasA
# 382     GasA
# 383     GasA
# 384     GasA
# 385     GasA
# 386     GasA
# 387     GasA
# 388     GasA
# 389     GasA
# 390     GasA
# 391     GasA
# 392     GasA
# 393     GasA
# 394     GasA
# 395     GasA
# 396     GasA
# 397     GasA
# 398     GasA
# 399     GasA
# 400     GasA
# 401     GasA
# 402     GasA
# 403     GasA
# 404     GasA
# 405     GasA
# 406     GasA
# 407     GasA
# 408     GasA
# 409     GasA
# 410     GasA
# 411     GasA
# 412     GasA
# 413     GasA
# 414     GasA
# 415     GasA
# 416     GasA
# 417     GasW
# 418     GasA
# 419     GasA
# 420     GasA
# 421     GasA
# 422     GasA
# 423     GasA
# 424     GasA
# 425     GasA
# 426     GasA
# 427     GasA
# 428     GasA
# 429     GasA
# 430     GasA
# 431     GasA
# 432     GasA
# 433     GasA
# 434     GasA
# 435     GasA
# 436     GasA
# 437     GasA
# 438     GasA
# 439     GasA
# 440     GasA
# 441     GasA
# 442     GasA
# 443     GasA
# 444     GasA
# 445     GasA
# 446     GasA
# 447     GasA
# 448     GasA
# 449     GasA
# 450     GasA
# 451     GasA
# 452     GasA
# 453     GasA
# 454     GasA
# 455     GasA
# 456     GasA
# 457     GasA
# 458     GasA
# 459     GasA
# 460     GasA
# 461     GasA
# 462     GasA
# 463     GasA
# 464     GasA
# 465     GasA
# 466     GasA
# 467     GasA
# 468     GasA
# 469     GasA
# 470     GasA
# 471     GasA
# 472     GasA
# 473     GasA
# 474     GasA
# 475     GasA
# 476     GasA
# 477     GasA
# 478     GasA
# 479     GasA
# 480     GasA
# 481     GasA
# 482     GasA
# 483     GasA
# 484     GasA
# 485     GasA
# 486     GasA
# 487     GasA
# 488     GasA
# 489     GasA
# 490     GasA
# 491     GasA
# 492     GasA
# 493     GasA
# 494     GasA
# 495     GasA
# 496     GasA
# 497     GasA
# 498     GasA
# 499     GasA
# 500     GasA
# 501     GasA
# 502     GasA
# 503     GasA
# 504     GasA
# 505     GasA
# 506     GasA
# 507     GasA
# 508     GasA
# 509     GasA
# 510     GasA
# 511     GasA
# 512     GasA
# 513     GasA
# 515     GasA
# 516     GasA
# 517     GasA
# 518     GasA
# 519     GasA
# 520     GasA
# 521     GasA
# 522     GasA
# 523     GasA
# 524     GasA
# 525     GasA
# 526     GasA
# 527     GasA
# 528     GasA
# 529     GasA
# 530     GasA
# 531     GasA
# 532     GasA
# 533     GasA
# 534     GasA
# 535     GasA
# 536     GasA
# 537     GasA
# 538     GasA
# 539     GasA
# 540     GasA
# 541     GasA
# 542     GasA
# 543     GasA
# 544     GasA
# 545     GasA
# 546     GasA
# 547     GasA
# 548     GasA
# 549     GasA
# 550     GasA
# 551     GasA
# 552     GasA
# 553     GasA
# 554     GasA
# 555     GasA
# 556     GasA
# 557     GasA
# 558     GasA
# 559     GasA
# 560     GasA
# 561     GasA
# 562     GasA
# 563     GasA
# 564     GasA
# 565     GasA
# 566     GasA
# 567     GasA
# 568     GasA
# 569     GasA
# 570     GasA
# 571     GasA
# 572     GasA
# 573     GasA
# 574     GasA
# 575     GasA
# 576     GasA
# 577     GasA
# 578     GasA
# 579     GasA
# 580     GasA
# 581     GasA
# 582     GasA
# 583     GasA
# 584     GasA
# 585     GasA
# 586     GasA
# 587     GasA
# 588     GasA
# 589     GasA
# 590     GasA
# 591     GasA
# 592     GasA
# 593     GasA
# 594     GasA
# 595     GasA
# 596     GasA
# 597     GasA
# 598     GasA
# 599     GasA
# 600     GasA
# 601     GasA
# 602     GasA
# 603     GasA
# 604     GasA
# 605     GasA
# 606     GasA
# 607     GasA
# 608     GasA
# 609     GasA
# 610     GasA
# 611     GasA
# 612     GasA
# 613     GasA
# 614     GasA
# 615     GasA
# 616     GasA
# 617     GasA
# 618     GasA
# 619     GasA
# 620     GasA
# 621     GasA
# 622     GasA
# 623     GasA
# 624     GasA
# 625     GasA
# 626     GasA
# 627     GasA
# 628     GasA
# 629     GasA
# 630     GasA
# 631     GasA
# 632     GasA
# 633     GasA
# 634     GasA
# 635     GasA
# 637     GasA
# 638     GasA
# 639     GasA
# 640     GasA
# 641     GasA
# 642     GasA
# 643     GasA
# 644     GasA
# 645     GasA
# 646     GasA
# 647     GasA
# 648     GasA
# 649     GasA
# 650     GasA
# 651     GasA
# 652     GasA
# 653     GasA
# 654     GasA
# 655     GasA
# 656     GasA
# 657     GasA
# 658     GasA
# 659     GasA
# 660     GasA
# 661     GasA
# 662     GasA
# 663     GasA
# 664     GasA
# 665     GasA
# 666     GasA
# 667     GasA
# 668     GasA
# 669     GasA
# 670     GasA
# 671     GasA
# 672     GasA
# 673     GasA
# 674     GasA
# 675     GasA
# 676     GasW
# 677     GasA
# 678     GasA
# 679     GasA
# 680     GasA
# 681     GasA
# 682     GasA
# 683     GasA
# 684     GasA
# 685     GasA
# 686     GasA
# 687     GasA
# 688     GasA
# 689     GasA
# 690     GasA
# 691     GasA
# 692     GasA
# 693     GasA
# 694     GasA
# 695     GasA
# 696     GasA
# 697     GasA
# 698     GasA
# 699     GasA
# 700     GasA
# 701     GasA
# 702     GasA
# 703     GasA
# 704     GasA
# 705     GasA
# 706     GasA
# 707     GasA
# 708     GasA
# 709     GasA
# 710     GasA
# 711     GasA
# 712     GasA
# 713     GasW
# 714     GasA
# 715     GasA
# 716     GasA
# 717     GasA
# 718     GasA
# 719     GasA
# 720     GasA
# 721     GasA
# 722     GasA
# 723     GasA
# 724     GasA
# 725     GasA
# 726     GasA
# 727     GasA
# 728     GasA
# 729     GasA
# 730     GasA
# 731     GasA
# 732     GasA
# 733     GasA
# 734     GasA
# 735     GasW
# 736     GasA
# 737     GasA
# 738     GasA
# 739     GasA
# 740     GasA
# 741     GasA
# 742     GasA
# 743     GasA
# 744     GasA
# 745     GasA
# 746     GasA
# 747     GasW
# 748     GasA
# 750     GasA
# 751     GasA
# 752     GasA
# 753     GasA
# 754     GasA
# 755     GasA
# 756     GasA
# 757     GasA
# 758     GasA
# 759     GasA
# 760     GasA
# 761     GasA
# 762     GasA
# 763     GasA
# 764     GasA
# 765     GasA
# 766     GasA
# 767     GasA
# 768     GasA
# 769     GasA
# 770     GasA
# 771     GasA
# 772     GasA
# 773     GasA
# 774     GasA
# 775     GasA
# 776     GasA
# 777     GasA
# 778     GasA
# 779     GasA
# 780     GasA
# 781     GasA
# 782     GasA
# 783     GasA
# 784     GasA
# 785     GasA
# 786     GasA
# 787     GasA
# 788     GasA
# 789     GasA
# 790     GasA
# 791     GasA
# 792     GasA
# 793     GasA
# 794     GasA
# 795     GasA
# 796     GasA
# 797     GasA
# 798     GasA
# 799     GasA
# 800     GasA
# 801     GasA
# 802     GasA
# 803     GasA
# 804     GasA
# 805     GasA
# 806     GasA
# 807     GasA
# 808     GasA
# 809     GasA
# 810     GasA
# 811     GasA
# 812     GasA
# 813     GasA
# 814     GasW
# 815     GasA
# 816     GasA
# 817     GasA
# 818     GasA
# 819     GasA
# 820     GasA
# 821     GasA
# 822     GasA
# 823     GasA
# 824     GasA
# 825     GasA
# 826     GasA
# 827     GasA
# 828     GasA
# 829     GasA
# 830     GasA
# 831     GasA
# 832     GasA
# 833     GasA
# 834     GasA
# 835     GasA
# 836     GasA
# 837     GasA
# 838     GasA
# 839     GasA
# 840     GasA
# 841     GasA
# 842     GasA
# 843     GasA
# 844     GasA
# 845     GasA
# 846     GasA
# 847     GasA
# 848     GasA
# 849     GasA
# 850     GasA
# 851     GasA
# 852     GasA
# 853     GasA
# 854     GasA
# 855     GasA
# 856     GasA
# 857     GasA
# 858     GasA
# 859     GasA
# 860     GasA
# 861     GasA
# 862     GasA
# 863     GasA
# 864     GasA
# 865     GasA
# 866     GasA
# 867     GasA
# 868     GasA
# 869     GasA
# 870     GasA
# 871     GasA
# 872     GasA
# 873     GasA
# 874     GasA
# 875     GasA
# 876     GasA
# 877     GasA
# 878     GasA
# 879     GasA
# 880     GasA
# 881     GasA
# 882     GasA
# 883     GasA
# 884     GasA
# 885     GasA
# 886     GasA
# 887     GasA
# 888     GasA
# 889     GasA
# 890     GasA
# 891     GasA
# 892     GasA
# 893     GasA
# 894     GasA
# 895     GasA
# 896     GasA
# 897     GasA
# 898     GasA
# 899     GasA
# 900     GasA
# 901     GasA
# 902     GasA
# 903     GasA
# 904     GasA
# 905     GasA
# 906     GasA
# 907     GasA
# 908     GasA
# 909     GasA
# 910     GasA
# 911     GasA
# 912     GasA
# 913     GasA
# 914     GasA
# 915     GasA
# 916     GasA
# 917     GasA
# 918     GasA
# 919     GasA
# 920     GasA
# 921     GasA
# 922     GasA
# 923     GasA
# 924     GasA
# 925     GasA
# 926     GasA
# 927     GasA
# 928     GasA
# 929     GasA
# 930     GasA
# 931     GasA
# 932     GasA
# 933     GasA
# 934     GasA
# 935     GasA
# 936     GasA
# 937     GasA
# 938     GasA
# 939     GasA
# 940     GasA
# 941     GasA
# 942     GasA
# 943     GasA
# 944     GasA
# 945     GasA
# 946     GasA
# 947     GasA
# 948     GasA
# 949     GasA
# 950     GasA
# 951     GasA
# 952     GasA
# 953     GasA
# 954     GasA
# 955     GasA
# 956     GasA
# 957     GasA
# 958     GasA
# 959     GasA
# 960     GasA
# 961     GasA
# 962     GasA
# 963     GasA
# 964     GasA
# 965     GasA
# 966     GasA
# 967     GasA
# 969     GasA
# 970     GasA
# 971     GasA
# 972     GasA
# 973     GasA
# 974     GasA
# 975     GasA
# 976     GasA
# 977     GasA
# 978     GasA
# 979     GasA
# 980     GasA
# 981     GasA
# 982     GasA
# 983     GasA
# 984     GasA
# 985     GasW
# 986     GasA
# 987     GasA
# 988     GasA
# 989     GasA
# 990     GasA
# 991     GasA
# 992     GasA
# 993     GasA
# 994     GasA
# 995     GasA
# 996     GasA
# 997     GasA
# 998     GasA
# 999     GasA
# 1000    GasW
# 1001    GasA
# 1002    GasA
# 1003    GasA
# 1004    GasA
# 1005    GasA
# 1006    GasA
# 1007    GasA
# 1008    GasA
# 1009    GasA
# 1010    GasA
# 1011    GasA
# 1012    GasA
# 1013    GasW
# 1014    GasA
# 1015    GasA
# 1016    GasA
# 1017    GasA
# 1018    GasA
# 1019    GasA
# 1020    GasA
# 1021    GasA
# 1022    GasA
# 1023    GasA
# 1024    GasA
# 1025    GasA
# 1026    GasA
# 1027    GasA
# 1028    GasA
# 1029    GasA
# 1030    GasA
# 1031    GasA
# 1032    GasA
# 1033    GasA
# 1034    GasA
# 1035    GasA
# 1036    GasA
# 1037    GasA
# 1038    GasA
# 1039    GasA
# 1040    GasA
# 1041    GasA
# 1042    GasA
# 1043    GasA
# 1044    GasA
# 1045    GasA
# 1046    GasA
# 1047    GasA
# 1048    GasA
# 1049    GasA
# 1050    GasA
# 1051    GasA
# 1052    GasA
# 1053    GasA
# 1054    GasA
# 1055    GasA
# 1056    GasA
# 1057    GasA
# 1058    GasA
# 1059    GasA
# 1060    GasA
# 1061    GasA
# 1062    GasA
# 1063    GasA
# 1064    GasA
# 1065    GasA
# 1066    GasA
# 1067    GasA
# 1068    GasA
# 1069    GasA
# 1070    GasA
# 1071    GasA
# 1072    GasA
# 1073    GasA
# 1074    GasA
# 1075    GasA
# 1076    GasA
# 1077    GasA
# 1078    GasA
# 1079    GasA
# 1080    GasA
# 1081    GasA
# 1082    GasA
# 1083    GasA
# 1084    GasA
# 1085    GasA
# 1086    GasA
# 1087    GasA
# 1088    GasA
# 1089    GasA
# 1091    GasA
# 1092    GasA
# 1093    GasA
# 1094    GasA
# 1095    GasA
# 1096    GasA
# 1097    GasA
# 1098    GasA
# 1099    GasA
# 1100    GasA
# 1101    GasA
# 1102    GasA
# 1103    GasA
# 1104    GasA
# 1105    GasA
# 1106    GasA
# 1107    GasA
# 1108    GasA
# 1109    GasA
# 1110    GasA
# 1111    GasA
# 1112    GasA
# 1113    GasA
# 1114    GasA
# 1115    GasA
# 1116    GasA
# 1117    GasA
# 1118    GasA
# 1119    GasA
# 1120    GasA
# 1121    GasA
# 1122    GasA
# 1123    GasA
# 1124    GasA
# 1125    GasA
# 1126    GasA
# 1127    GasA
# 1128    GasA
# 1129    GasA
# 1130    GasA
# 1131    GasA
# 1132    GasW
# 1133    GasA
# 1134    GasA
# 1135    GasA
# 1136    GasA
# 1137    GasA
# 1138    GasA
# 1139    GasA
# 1140    GasA
# 1141    GasA
# 1142    GasA
# 1143    GasA
# 1145    GasA
# 1146    GasA
# 1147    GasA
# 1148    GasA
# 1149    GasA
# 1150    GasA
# 1151    GasA
# 1152    GasA
# 1153    GasA
# 1154    GasA
# 1155    GasA
# 1156    GasA
# 1157    GasA
# 1158    GasA
# 1159    GasA
# 1160    GasA
# 1161    GasA
# 1162    GasA
# 1163    GasA
# 1164    GasA
# 1165    GasA
# 1166    GasA
# 1167    GasA
# 1168    GasA
# 1169    GasA
# 1170    GasA
# 1171    GasA
# 1172    GasA
# 1173    GasA
# 1174    GasA
# 1175    GasA
# 1176    GasA
# 1177    GasA
# 1178    GasA
# 1179    GasA
# 1180    GasA
# 1181    GasA
# 1182    GasA
# 1183    GasA
# 1184    GasA
# 1185    GasA
# 1186    GasA
# 1187    GasA
# 1188    GasA
# 1189    GasA
# 1190    GasA
# 1191    GasA
# 1192    GasA
# 1193    GasA
# 1194    GasA
# 1195    GasA
# 1196    GasA
# 1197    GasA
# 1198    GasA
# 1199    GasA
# 1200    GasA
# 1201    GasA
# 1202    GasA
# 1203    GasA
# 1204    GasA
# 1205    GasA
# 1206    GasA
# 1207    GasA
# 1208    GasA
# 1209    GasA
# 1210    GasA
# 1211    GasA
# 1212    GasA
# 1213    GasA
# 1214    GasA
# 1215    GasA
# 1216    GasA
# 1217    GasA
# 1218    GasA
# 1219    GasA
# 1220    GasA
# 1221    GasA
# 1222    GasA
# 1223    GasA
# 1224    GasA
# 1225    GasA
# 1226    GasA
# 1227    GasA
# 1228    GasA
# 1229    GasA
# 1230    GasA
# 1231    GasA
# 1232    GasA
# 1233    GasA
# 1234    GasA
# 1235    GasA
# 1236    GasA
# 1237    GasA
# 1238    GasA
# 1239    GasA
# 1240    GasA
# 1241    GasA
# 1242    GasA
# 1243    GasA
# 1244    GasA
# 1245    GasA
# 1246    GasA
# 1247    GasA
# 1249    GasA
# 1250    GasA
# 1251    GasA
# 1252    GasA
# 1253    GasA
# 1254    GasA
# 1255    GasA
# 1256    GasA
# 1257    GasA
# 1258    GasA
# 1259    GasA
# 1260    GasA
# 1261    GasA
# 1262    GasA
# 1263    GasA
# 1264    GasA
# 1265    GasA
# 1266    GasA
# 1267    GasA
# 1268    GasA
# 1269    GasW
# 1270    GasA
# 1271    GasA
# 1272    GasA
# 1273    GasA
# 1274    GasA
# 1275    GasA
# 1276    GasA
# 1277    GasA
# 1278    GasA
# 1279    GasA
# 1280    GasA
# 1281    GasA
# 1282    GasA
# 1283    GasA
# 1284    GasA
# 1285    GasA
# 1286    GasA
# 1287    GasA
# 1288    GasA
# 1289    GasA
# 1290    GasA
# 1291    GasA
# 1292    GasA
# 1293    GasA
# 1294    GasA
# 1295    GasA
# 1296    GasA
# 1297    GasA
# 1298    GasA
# 1299    GasA
# 1300    GasA
# 1301    GasA
# 1302    GasA
# 1303    GasA
# 1304    GasA
# 1305    GasA
# 1306    GasA
# 1307    GasA
# 1308    GasA
# 1309    GasA
# 1310    GasA
# 1311    GasA
# 1312    GasA
# 1313    GasA
# 1314    GasA
# 1315    GasA
# 1316    GasA
# 1317    GasA
# 1318    GasA
# 1319    GasA
# 1320    GasA
# 1322    GasA
# 1323    GasA
# 1324    GasA
# 1325    GasA
# 1326    GasA
# 1327    GasA
# 1328    GasW
# 1329    GasA
# 1330    GasA
# 1331    GasA
# 1332    GasA
# 1333    GasA
# 1334    GasA
# 1335    GasA
# 1336    GasA
# 1338    GasA
# 1339    GasA
# 1340    GasA
# 1341    GasA
# 1342    GasA
# 1343    GasA
# 1344    GasA
# 1345    GasA
# 1346    GasA
# 1347    GasA
# 1348    GasA
# 1350    GasA
# 1351    GasA
# 1352    GasA
# 1353    GasA
# 1354    GasA
# 1355    GasA
# 1356    GasA
# 1357    GasA
# 1358    GasA
# 1359    GasA
# 1360    GasA
# 1361    GasA
# 1362    GasA
# 1363    GasA
# 1364    GasA
# 1365    GasA
# 1366    GasA
# 1367    GasA
# 1368    GasA
# 1369    GasA
# 1370    GasA
# 1371    GasA
# 1372    GasA
# 1373    GasA
# 1374    GasA
# 1375    GasA
# 1376    GasA
# 1377    GasA
# 1378    GasA
# 1379    GasA
# 1380    GasA
# 1381    GasA
# 1382    GasA
# 1383    GasA
# 1384    GasA
# 1385    GasA
# 1386    GasA
# 1387    GasW
# 1388    GasA
# 1389    GasA
# 1390    GasA
# 1391    GasA
# 1392    GasA
# 1393    GasA
# 1394    GasA
# 1395    GasA
# 1396    GasA
# 1397    GasA
# 1398    GasA
# 1399    GasA
# 1400    GasA
# 1401    GasA
# 1402    GasA
# 1403    GasA
# 1404    GasA
# 1405    GasA
# 1406    GasA
# 1407    GasA
# 1408    GasA
# 1409    GasA
# 1410    GasA
# 1411    GasA
# 1413    GasA
# 1414    GasA
# 1415    GasA
# 1416    GasA
# 1417    GasA
# 1418    GasA
# 1419    GasA
# 1420    GasA
# 1421    GasA
# 1422    GasA
# 1423    GasA
# 1424    GasA
# 1425    GasA
# 1426    GasA
# 1427    GasA
# 1428    GasA
# 1429    GasA
# 1430    GasA
# 1431    GasA
# 1432    GasA
# 1433    GasA
# 1434    GasA
# 1435    GasA
# 1436    GasA
# 1437    GasA
# 1438    GasA
# 1439    GasA
# 1440    GasA
# 1441    GasA
# 1442    GasA
# 1444    GasA
# 1445    GasA
# 1446    GasA
# 1447    GasA
# 1448    GasA
# 1449    GasA
# 1450    GasA
# 1451    GasA
# 1452    GasA
# 1453    GasA
# 1454    GasA
# 1455    GasA
# 1456    GasA
# 1457    GasA
# 1458    GasA
# 1459    GasA
# Name: Heating, dtype: object

# %%
# using lambda and a function change 2Story to 2Storey and 1Story to 1Storey

# see what the values are in this column
print('before modification values are: ',  df.HouseStyle.unique())

# create a function that can change this value
def change_spelling(style_name):
    """
    changes the spelling of story to storey in a string
    input: string
    output: modified name of the style
    """
    if style_name == '2Story': return '2Storey'
    elif style_name == '1Story': return '1Storey'
    else: return style_name

# apply the changes on HouseStyle
df.loc[:, 'HouseStyle'] = df.loc[:, 'HouseStyle'].apply(lambda x: change_spelling(x))

# print the new values
print('after the modification values are: ',  df.HouseStyle.unique())
# Out:
# before modification values are:  ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# after the modification values are:  ['2Storey' '1Storey' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']

# %% [markdown]
# ## Your turn...
#
# Dataset: [link](https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows)

# %%
# read the dataset
df = pd.read_csv('./content/imdb_movies/imdb_top_1000.csv')

# %%
# see the first few records
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# How many movies are there?
df.shape[0]
# len(df)
# Out:
# 1000

# %%
# How many columns do we have?
df.shape[1]
# len(df.columns)
# Out:
# 16

# %%
# are there any duplicates?
df.duplicated().sum()
# Out:
# 0

# %%
# are there any duplicates in the Released_Year column?
df.duplicated(subset=['Released_Year']).sum()
# Out:
# 900

# %%
# take a look at the datatypes
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
# Convert 'Released_Year' to int
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')
df['Released_Year'].fillna(-1, inplace=True)
df['Released_Year'] = df['Released_Year'].astype('int')
# Convert 'Gross' to float
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')
# Now, you can check the data types of your DataFrame
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year      int64
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
# take a look at the record for Fight Club
df[df.Series_Title == 'Fight Club']
# Out:
#                                          Poster_Link Series_Title  \
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...   Fight Club
#
#    Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# 9           1999           A  139 min  Drama          8.8
#
#                                             Overview  Meta_score  \
# 9  An insomniac office worker and a devil-may-car...        66.0
#
#         Director      Star1          Star2      Star3         Star4  \
# 9  David Fincher  Brad Pitt  Edward Norton  Meat Loaf  Zach Grenier
#
#    No_of_Votes  Gross
# 9      1854740    NaN

# %%
# which are the movies released after the year 2000?
df[df.Released_Year > 2000]
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 21   https://m.media-amazon.com/images/M/MV5BZjdkOT...
# 22   https://m.media-amazon.com/images/M/MV5BOTMwYj...
# 23   https://m.media-amazon.com/images/M/MV5BMjlmZm...
# 33   https://m.media-amazon.com/images/M/MV5BNGVjNW...
# 34   https://m.media-amazon.com/images/M/MV5BOTA5ND...
# 358             Gena Rowlands        88656    NaN
# 359                Steve Zahn       441614    NaN
# 360                Brian Howe       448930    NaN
# 361            Kagiso Kuypers       499439    NaN
# 362              Julia Stiles       604694    NaN
# 363                Jin-mo Joo        50610    NaN
# 364                Clive Owen       738512    NaN
# 365         Marie-Josée Croze       103284    NaN
# 366               Safak Sezer        56960    NaN
# 367             Patton Oswalt       641645    NaN
# 368            Jeffrey Wright       582239    NaN
# 369              Daryl Hannah       683900    NaN
# 370          Nataliya Vdovina        42399    NaN
# 371             Kim Young-Min        77520    NaN
# 372              Mabel Rivera        77554    NaN
# 373             Paul Giamatti       176151    NaN
# 374             Jaya Bachchan        63460    NaN
# 375    Anthony Chau-Sang Wong       117857    NaN
# 376           Keira Knightley      1015122    NaN
# 377             Jessica Lange       415218    NaN
# 378                 Jason Lee       657047    NaN
# 379              Song Wok-suk        45403    NaN
# 380         Harriet Andersson       137963    NaN
# 381             Altan Erkekli        33592    NaN
# 382            Holmes Osborne       740086    NaN
# 463          Jamie Lee Curtis       454203    NaN
# 464        Saswata Chatterjee       111478    NaN
# 465             Mayu Matsuoka        62754    NaN
# 466            Azhy Robertson       246644    NaN
# 467               Amira Casar       212651    NaN
# 468              Sharon Percy        53818    NaN
# 469               Bob Balaban       139114    NaN
# 470              Rachel House       111483    NaN
# 471            Annalise Basso       189400    NaN
# 472               Jack Reynor        85109    NaN
# 473              Mark Ruffalo       587775    NaN
# 474                 Riz Ahmed       466134    NaN
# 475             Taika Waititi       297918    NaN
# 476         Michael Stuhlbarg       594181    NaN
# 477          Domhnall Gleeson       860823    NaN
# 478              Ariane Labed       141457    NaN
# 479              James McAvoy       659763    NaN
# 480       Ahmet Mümtaz Taylan        41995    NaN
# 481            James Cromwell       230624    NaN
# 482           Brendan Gleeson       600004    NaN
# 483         Alexandre Tharaud        93090    NaN
# 484             Harvey Keitel       324720    NaN
# 485                Reda Kateb        93560    NaN
# 486                Rosie Shaw       335152    NaN
# 487               Henrik Dahl       205609    NaN
# 488            Nathalie Boltt       638202    NaN
# 489             Mark Margolis       289415    NaN
# 490                Dara Singh        47720    NaN
# 491              Elijah Smith       335533    NaN
# 492        Alexandru Potocean        56625    NaN
# 493             Leonard Nimoy       577336    NaN
# 494      Elizabeth Berrington       390334    NaN
# 495            Ellen Crawford       174125    NaN
# 496                  Ryô Kase       154011    NaN
# 497            Kim Uylenbroek       107290    NaN
# 498                      Tabu       580708    NaN
# 499         Jason Schwartzman       199696    NaN
# 500              Émile Vallée        31476    NaN
# 501                 Kad Merad        57430    NaN
# 502              Jeff Bridges       939644    NaN
# 503                Lucy Davis       512249    NaN
# 504       Zarah Jane McKenzie        51325    NaN
# 505               Emmy Rossum       419420    NaN
# 506         Richard Griffiths       552493    NaN
# 507                Ziyi Zhang       173999    NaN
# 508            Leonor Watling       104691    NaN
# 509          Georges Siatidis        44618    NaN
# 510          Beau Billingslea        42897    NaN
# 511                Clive Owen       508771    NaN
# 513             Michael Caine       465113    NaN
# 515              Jeanne Bates       322031    NaN
# 569             Jeremy Strong       237392    NaN
# 570            Shishir Sharma        25344    NaN
# 571            Lauren Ridloff        27187    NaN
# 572               Mina Sadati        51240    NaN
# 573                 Tom Hardy       555092    NaN
# 574               Edoardo Leo        57168    NaN
# 575             Kevin Costner       200876    NaN
# 576             Sally Hawkins        61594    NaN
# 577            Diljit Dosanjh        27175    NaN
# 578             Ralph Fiennes       118035    NaN
# 579              Disha Patani        40416    NaN
# 580              Lucas Hedges       246963    NaN
# 581      Mikkel Boe Følsgaard        35539    NaN
# 582                Donnie Yen       556608    NaN
# 583        Scarlett Johansson       663649    NaN
# 584            Walton Goggins       517059    NaN
# 585             Eliza Scanlen       143250    NaN
# 586           Robert Gulaczyk        50778    NaN
# 587           Paddy Considine        51841    NaN
# 588            Pauline Burlet        45002    NaN
# 589          Carlo Buccirosso        81125    NaN
# 590             Lillete Dubey        50523    NaN
# 591           Dolly Ahluwalia        39710    NaN
# 592               Jamie Chung       410983    NaN
# 593              Lydia Wilson       303032    NaN
# 594               Priya Anand        33618    NaN
# 595        Masahiko Nishimura        73690    NaN
# 596                 Tony Hale       203177    NaN
# 597         Donald Sutherland       108399    NaN
# 598               Bill Murray       318789    NaN
# 599            Craig Ferguson       305611    NaN
# 600                 Brad Pitt       362942    NaN
# 601             Yukito Nishii        35713    NaN
# 602               Ho-jin Chun       111252    NaN
# 603         Stellan Skarsgård       423010    NaN
# 604          Catherine Keener       421244    NaN
# 605               Hee-won Kim        62848    NaN
# 606            Neil Brown Jr.       179264    NaN
# 607                Je-mun Yun        52758    NaN
# 608             Yoo-Jeong Kim        58468    NaN
# 609                 Ken Stott       601408    NaN
# 610              Ulrich Tukur        68715    NaN
# 611                Lena Endre       208994    NaN
# 612             Jeremy Strong        89896    NaN
# 613               Lars Ranthe        33931    NaN
# 614               Melissa Leo       340584    NaN
# 615              Leland Orser       564791    NaN
# 616       Zac Mattoon O'Brien       190748    NaN
# 617           Gerard Hendrick       110656    NaN
# 618               Andy Serkis       757377    NaN
# 619               Nursel Köse        30827    NaN
# 620             Saoirse Ronan       251370    NaN
# 621             Albert Brooks       571571    NaN
# 622               Josh Brolin       392449    NaN
# 623        Michelle Rodriguez      1118998    NaN
# 624             Linh Dan Pham       216421    NaN
# 625           Rudy Youngblood       291018    NaN
# 626              Greg Kinnear       439856    NaN
# 627                Bill Nighy       463466    NaN
# 628              Julia Ormond       589160    NaN
# 629               Kirron Kher        49050    NaN
# 630             Paprika Steen        45717    NaN
# 631         Donald Sutherland       258924    NaN
# 632            Tessa Mitchell        51980    NaN
# 633               Aya Okamoto        31658    NaN
# 634                Alan Tudyk       283310    NaN
# 635            Robert Patrick       234207    NaN
# 636           Linda Zilliacus        35682    NaN
# 637              Ryan Gosling       520284    NaN
# 638            Mercedes Morán        96703    NaN
# 639            Lyubov Agapova        42673    NaN
# 640             Monica Viegas        50622    NaN
# 642                  JB Blanc       129022    NaN
# 643             Wiley Wiggins        60684    NaN
# 651              Cameron Diaz       613941    NaN
# 720            Carlos Peralta       140375    NaN
# 721                  Ian Hart        25198    NaN
# 722           Julian Dennison       478586    NaN
# 723               Teo Briones       205444    NaN
# 724          Catherine Keener       492851    NaN
# 725                Simon Pegg       291257    NaN
# 726               Ida Engvoll        47444    NaN
# 727      Cori Gonzalez-Macuer       157498    NaN
# 728         Nanako Matsushima        32798    NaN
# 729              Sophie Perry       404182    NaN
# 730             Michael Caine       590440    NaN
# 731                Laura Dern       344312    NaN
# 732             Nick Offerman       123210    NaN
# 733        Andrea Riseborough       580291    NaN
# 734          Aurélien Recoing       138741    NaN
# 735               Amrita Puri        32628    NaN
# 736      Geert Van Rampelberg        39379    NaN
# 737        Scarlett Johansson       736182    NaN
# 738              Kumud Mishra        39501    NaN
# 739              Bob Odenkirk       112298    NaN
# 740           Sarah Silverman       380195    NaN
# 741          Marion Cotillard        56720    NaN
# 742                  Lucy Liu        77071    NaN
# 743               Kurt Fuller       388089    NaN
# 744           Elizabeth Banks       323982    NaN
# 745          Orto Ignatiussen       769145    NaN
# 746      Benedict Cumberbatch       463188    NaN
# 747              Andrew Adote        73964    NaN
# 748               Rooney Mara       624982    NaN
# 749               Kevin Bacon       645512    NaN
# 750                  Ed Helms       717559    NaN
# 751                Judi Dench       630614    NaN
# 752              Jacki Weaver       661871    NaN
# 753                Alan Arkin       572581    NaN
# 754        Chloë Grace Moretz       472242    NaN
# 755                Bill Nighy       479120    NaN
# 756          Tomoko Yamaguchi       125317    NaN
# 757              Sam Rockwell       103330    NaN
# 758               Tôru Furuya        71379    NaN
# 759          Gattlin Griffith       239203    NaN
# 760           Anthony Edwards        81446    NaN
# 761            Ayami Kakiuchi        60368    NaN
# 762                 Yû Kashii        28630    NaN
# 763               Andrew Shim       115576    NaN
# 764             Sonoya Mizuno       474141    NaN
# 765        Neeral Mulchandani        32001    NaN
# 766          Kerry Washington       175355    NaN
# 767           Anthony Edwards       466080    NaN
# 768                  Lucy Liu       299524    NaN
# 769            Natalie Dessay        28003    NaN
# 770      Alexandra Maria Lara        61609    NaN
# 771              Donna Murphy       405922    NaN
# 772              Halina Reijn        72643    NaN
# 773               Randy Quaid       323103    NaN
# 774              Logan Lerman       288797    NaN
# 775           Karina Arroyave       419483    NaN
# 776            Siu-Lung Leung       127250    NaN
# 777                 Brian Cox       434841    NaN
# 778              John Sharian       358432    NaN
# 779            Clifton Powell       138356    NaN
# 780                Anna Faris       415074    NaN
# 781                Eric Sykes       548619    NaN
# 782            Radha Mitchell       329592    NaN
# 783         Jennifer Saunders       197761    NaN
# 784          William Atherton       400049    NaN
# 785           Anne-Marie Duff        25938    NaN
# 786             Florian Lukas       137981    NaN
# 787              Sarah Bolger        40403    NaN
# 788              Dianne Wiest       142863    NaN
# 789             Tilda Swinton       178565    NaN
# 790                 Eric Bana       364254    NaN
# 791                Liam Aiken       246840    NaN
# 792       Wotan Wilke Möhring        90842    NaN
# 794        Theodore Liscinski        31957    NaN
# 795                Matt Damon       516372    NaN
# 798            Matthew Edison        29999    NaN
# 802              Tom Berenger       390247    NaN
# 877              Bill Pullman        60408    NaN
# 878               Michelle La       140840    NaN
# 879              Emile Hirsch       551309    NaN
# 880           Marina Vasileva        29765    NaN
# 881        Christopher Rivera        95181    NaN
# 882           Charlie Pye Jr.        46739    NaN
# 883           Octavia Spencer        99643    NaN
# 884            Dakota Johnson        66346    NaN
# 885               Burak Yigit        52903    NaN
# 886                Elit Iscan        35785    NaN
# 887                Vin Diesel       569974    NaN
# 888             Eiza González       439406    NaN
# 889         Jennifer Connelly        58371    NaN
# 890                  Amy Ryan       287659    NaN
# 891               Huck Milner       250057    NaN
# 892           Auli'i Cravalho       272784    NaN
# 893              Jon Bernthal       371291    NaN
# 894           Phylicia Rashad       247666    NaN
# 895     Vladimir Vdovichenkov        49397    NaN
# 896            Gil Birmingham       204175    NaN
# 897           Mare Winningham        94212    NaN
# 898          Kodi Smit-McPhee       411599    NaN
# 899              Aura Garrido        57549    NaN
# 900            Donny Alamsyah       190531    NaN
# 901           America Ferrera       228132    NaN
# 902          Tatsuya Fujiwara        80939    NaN
# 903             Greg Grunberg       334312    NaN
# 904          Hailee Steinfeld       311822    NaN
# 905               Wil Johnson        38491    NaN
# 906             Russell Brand       500851    NaN
# 907       Bryce Dallas Howard       315426    NaN
# 908          Garrett M. Brown       524081    NaN
# 909              Manuel Morón        63882    NaN
# 910    Philip Seymour Hoffman       369529    NaN
# 911            Marisa Paredes       138959    NaN
# 912           Abigail Breslin       520041    NaN
# 913           Jennifer Ulrich       102742    NaN
# 914               Mark Strong       583158    NaN
# 915                  Jae Head       293266    NaN
# 916               Hiam Abbass        41544    NaN
# 917              Michael Ealy       286770    NaN
# 918               Josef Altin       227760    NaN
# 919              Ian McKellen       255036    NaN
# 920                Mick Lally        31779    NaN
# 921       Christopher Plummer       339757    NaN
# 922         Michelle Monaghan       250590    NaN
# 923        Emmanuelle Seigner        82781    NaN
# 924                    Yun Qu        72863    NaN
# 925              Rufus Sewell       354728    NaN
# 926          Stuart Wolfenden        49728    NaN
# 927            Michael Gambon       474827    NaN
# 928              Dominic West       732876    NaN
# 929             Matthew Goode       206294    NaN
# 930             Malin Akerman       500799    NaN
# 931          Bridget Moynahan       294140    NaN
# 932                 Ken Leung       379020    NaN
# 933          Catherine Keener        83158    NaN
# 934             Chase Ellison        65939    NaN
# 935      Joséphine Lebas-Joly        67360    NaN
# 936           Dominique Pinon        70925    NaN
# 937             Paul Benjamin        67370    NaN
# 938              Danny Huston       224545    NaN
# 939                Ji-Eun Lim        62659    NaN
# 940            Radha Mitchell       198677    NaN
# 941            Rosario Dawson       169708    NaN
# 942            Melora Walters       451479    NaN
# 943               Alex Palmer       376853    NaN
# 945               Ben Stiller       266842    NaN
# 946         Ana López Mercado       115827    NaN
# 947              Maggie Smith       658185    NaN
# 948              Alakina Mann       337651    NaN
# 949          Rachel Griffiths       240714    NaN
# 950              Rachel Weisz       243729    NaN
# 951             Max von Sydow       508417    NaN

# %%
# which are the 2 most famouse ones? (look at the number of votes!)
df[df.Released_Year > 2000].sort_values('No_of_Votes', ascending=False).head(2)
# Out:
#                                          Poster_Link     Series_Title  \
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...  The Dark Knight
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...        Inception
#
#    Released_Year Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           2008          UA  152 min       Action, Crime, Drama          9.0
# 8           2010          UA  148 min  Action, Adventure, Sci-Fi          8.8
#
#                                             Overview  Meta_score  \
# 2  When the menace known as the Joker wreaks havo...        84.0
# 8  A thief who steals corporate secrets through t...        74.0
#
#             Director              Star1                 Star2          Star3  \
# 2  Christopher Nolan     Christian Bale          Heath Ledger  Aaron Eckhart
# 8  Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt    Elliot Page
#
#            Star4  No_of_Votes  Gross
# 2  Michael Caine      2303232    NaN
# 8   Ken Watanabe      2067042    NaN

# %%
# look at the oldest movie in this dataset
df[df.Released_Year > 0].sort_values('Released_Year').head(1)
# Out:
#                                            Poster_Link  \
# 321  https://m.media-amazon.com/images/M/MV5BNWJiNG...
#
#                      Series_Title  Released_Year Certificate Runtime  \
# 321  Das Cabinet des Dr. Caligari           1920         NaN  76 min
#
#                         Genre  IMDB_Rating  \
# 321  Fantasy, Horror, Mystery          8.1
#
#                                               Overview  Meta_score  \
# 321  Hypnotist Dr. Caligari uses a somnambulist, Ce...         NaN
#
#          Director          Star1         Star2            Star3        Star4  \
# 321  Robert Wiene  Werner Krauss  Conrad Veidt  Friedrich Feher  Lil Dagover
#
#      No_of_Votes  Gross
# 321        57428    NaN

# %%
# How to see the latest movie?
df.sort_values('Released_Year', ascending=False).head(1)
# Out:
#                                            Poster_Link Series_Title  \
# 205  https://m.media-amazon.com/images/M/MV5BZGE1MD...         Soul
#
#      Released_Year Certificate  Runtime                         Genre  \
# 205           2020           U  100 min  Animation, Adventure, Comedy
#
#      IMDB_Rating                                           Overview  \
# 205          8.1  After landing the gig of a lifetime, a New Yor...
#
#      Meta_score     Director        Star1       Star2     Star3  \
# 205        83.0  Pete Docter  Kemp Powers  Jamie Foxx  Tina Fey
#
#              Star4  No_of_Votes  Gross
# 205  Graham Norton       159171    NaN

# %%
# group the movies based on the first actor and sort by the number of movies
# they have played in
# pd.set_option('display.max_rows', None)
df.groupby(by='Star1').size()
# Out:
# Star1
# Aamir Khan                    7
# Aaron Taylor-Johnson          1
# Abhay Deol                    1
# Abraham Attah                 1
# Adam Driver                   1
# Adrian Molina                 1
# Adrien Brody                  2
# Ajay Devgn                    1
# Akshay Kumar                  4
# Al Pacino                    10
# Alain Delon                   1
# Alan Mak                      1
# Alec Guinness                 1
# Alejandro Jodorowsky          1
# Aleksandr Antonov             1
# Aleksey Kravchenko            1
# Aleksey Serebryakov           1
# Alia Bhatt                    1
# Alicia Vikander               1
# Alisa Freyndlikh              1
# Amit Sadh                     1
# Amitabh Bachchan              1
# Amole Gupte                   1
# Amy Adams                     1
# Amy Poehler                   1
# Anamaria Marinca              1
# Anand Gandhi                  1
# William Holden                4
# William Keighley              1
# William Powell                1
# William Shatner               1
# Winona Ryder                  1
# Won Bin                       1
# Woody Allen                   4
# Yalitza Aparicio              1
# Yash                          1
# Yasuo Yamada                  1
# Yoko Honna                    1
# Yul Brynner                   1
# Yun-Fat Chow                  3
# Yves Montand                  1
# Yôji Matsuda                  1
# Zach Galifianakis             1
# Zain Al Rafeea                1
# Zbigniew Zamachowski          1
# Zooey Deschanel               1
# Çetin Tekindor                1
# Éric Toledano                 1
# Ömer Faruk Sorak              1
# dtype: int64

# %%
# What are the Certificate types?
df['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
# Which movie descriptions have NASA in their Overview?
df[df['Overview'].str.contains("NASA")]
# Out:
#                                            Poster_Link    Series_Title  \
# 575  https://m.media-amazon.com/images/M/MV5BMzg2Mz...  Hidden Figures
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...       Apollo 13
#
#      Released_Year Certificate  Runtime                      Genre  \
# 575           2016          UA  127 min  Biography, Drama, History
# 966             -1           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 575          7.8  The story of a team of female African-American...
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score        Director             Star1            Star2  \
# 575        74.0  Theodore Melfi  Taraji P. Henson  Octavia Spencer
# 966        77.0      Ron Howard         Tom Hanks      Bill Paxton
#
#              Star3          Star4  No_of_Votes  Gross
# 575  Janelle Monáe  Kevin Costner       200876    NaN
# 966    Kevin Bacon    Gary Sinise       269197    NaN

# %%
# create a function that changes "The Dark Knight" movie name to "Batman"
# in the Series_Title



# apply the changes on Series_Title

# %%
# print the 'Series_Title' in df_movies to see the value has changed

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data manipulation
# create a column called decade that has the decade in which the house was built
df.loc[:, 'decade'] = df.YearBuilt // 10 * 10
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam    2Storey            7            5       2003
# 1          Norm     1Fam    1Storey            6            8       1976
# 2          Norm     1Fam    2Storey            7            5       2001
# 3          Norm     1Fam    2Storey            7            5       1915
# 4          Norm     1Fam    2Storey            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam    2Storey            6            5       1999
# 1456       Norm     1Fam    1Storey            6            6       1978
# 1457       Norm     1Fam    2Storey            7            9       1941
# 1458       Norm     1Fam    1Storey            5            6       1950
# 1459       Norm     1Fam    1Storey            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd        NaN
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
# 1458          1996       Hip  CompShg     MetalSd     MetalSd        NaN
# 1459          1965     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice  decade
# 0           Normal     208500    2000
# 1           Normal     181500    1970
# 2           Normal     223500    2000
# 3          Abnorml     140000    1910
# 4           Normal     250000    2000
# ...            ...        ...     ...
# 1455        Normal     175000    1990
# 1456        Normal     210000    1970
# 1457        Normal     266500    1940
# 1458        Normal     142125    1950
# 1459        Normal     147500    1960
#
# [1460 rows x 82 columns]

# %%
# Using groupby(), plot the number of houses built each decade

df.groupby(by='decade').size().plot(kind='bar')
# Out:
# <Axes: xlabel='decade'>

# %%
# Using groupby(), plot the number of 2Storey houses built each decade

df_2storey = df[df['HouseStyle']=='2Storey'].reset_index(drop=True)
df_2storey
df_2storey.groupby(by='decade').size().plot(kind='bar')
# Out:
# <Axes: xlabel='decade'>

# %% [markdown]
# ### df.corr()
#
# The correlation matrix is a square matrix that displays the pairwise correlations between all numeric columns in the DataFrame. It is a valuable tool for understanding the relationships and dependencies between different variables in your dataset.
#
# The correlation coefficient, which ranges from -1 to 1, quantifies the strength and direction of the linear relationship between two variables:
#
# A value of 1 indicates a perfect positive linear correlation, meaning that as one variable increases, the other also increases proportionally.
# A value of -1 indicates a perfect negative linear correlation, meaning that as one variable increases, the other decreases proportionally.
# A value close to 0 indicates a weak or no linear correlation between the variables.

# %%
# Correlation map to see how features are correlated with SalePrice
corrmat = df.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[165], line 2
#       1 # Correlation map to see how features are correlated with SalePrice
# ----> 2 corrmat = df.corr()
#       3 plt.subplots(figsize=(12,9))
#       4 sns.heatmap(corrmat, vmax=0.9, square=True, cmap='coolwarm')
#
# File ~/.conda/envs/tensorflow_ml/lib/python3.12/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.conda/envs/tensorflow_ml/lib/python3.12/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/.conda/envs/tensorflow_ml/lib/python3.12/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/.conda/envs/tensorflow_ml/lib/python3.12/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'RL'

# %%
# plot GrLivArea against SalePrice
# do you see anything out of the ordinary?
fig, ax = plt.subplots()
ax.scatter(x = df['GrLivArea'], y = df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
#Deleting outliers
df = df.drop(df[df['GrLivArea']>4000].index)

fig, ax = plt.subplots()
ax.scatter(df['GrLivArea'], df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
#  ### displot (short for "distribution plot")
#
#  This is a function used to visualize the univariate distribution of a dataset. It allows you to plot the distribution of a single continuous variable, providing insights into its underlying data distribution, including the shape, central tendency, and spread of the data.
#
#  **data** is the data you want to visualize. It can be a Pandas Series, NumPy array, or a list containing your dataset.
#
# **bins** (optional) controls the number of bins or intervals into which the data is divided for the histogram. More bins provide finer granularity.
#
# **kde** (optional) stands for "Kernel Density Estimation" and is a way to estimate the probability density function of the data. Setting it to True adds a smoothed curve to the plot, which can provide additional insights into the data's distribution.

# %%
# let's make a histogram for sales
sns.displot(df['SalePrice'], kde=True)

# %% [markdown]
# The catplot function is a powerful and flexible way to create categorical plots. Categorical plots are used to visualize the distribution of one variable within different categories or the relationship between two categorical variables.

# %%
feature = 'OverallQual' # add the name of the column to this list - 'MoSold'

sns.set_style('whitegrid')
sns.catplot(x=feature, kind="count", palette="PuRd_r", data=df)

# %% [markdown]
# ### Your Turn

# %%
# create a column called decade that has the decade in which the house was built

# %%
# Using groupby(), plot the number of movies
# that have been made each decade in the history of cinema.

# %%
# build the correlation matrix and plot it with seaborn!
#Correlation map to see how features are correlated with SalePrice

# %%
# plot a histogram for the "No_of_Votes"

# %% [markdown]
#  ## Missing Values
#  When handling these null values we have to divide them into three categories. [Reference](https://cjasn.asnjournals.org/content/9/7/1328.abstract)
#
#
# ![pic](https://github.com/mitramir55/teaching_material/blob/master/missing%20values.png?raw=true)
#
#
# **Missing Completely at Random (MCAR):** This means that there is no relationship between the missing values themselves and any other feature or observation in the dataset. These are just missing randomly and without any pattern. Like when a questionnaire is lost or some parts of a survey paper are soaked and you cannot read what it's saying. Therefore we can simply ignore them.
#
# **Missing at Random (MAR):** Means there is a pattern and relationship between the missing values and the observed values, like when the survey is about mental and physical health, male participants are less likely to know their waist circumference or boob size. We can again ignore these missing values and drop the feature or examples from our dataset. In this case we say that missing values are only related to the observed features (gender).
#
# **Missing Not at Random (MNAR):** This is a missing value that cannot and should not be ignored. We have to model and see when were the values missing and what was the reason for it. For instance, men might not answer questions about depression because of their depression. In this case we say that the missing values are related to themselves (depression) as well as to the observed features (gender).

# %%
# how to see the total number of null values?
df.isnull().sum()

# %%
# which one has the most null values?
df.isnull().sum().sort_values(ascending=False)

# %%
# a function for an interpretable visualization of nulls
def detect_nulls(df, n=30):
    """
    A function for viewing the null values present in the dataset
    input: takes in a dataframe and the n for the n most empty columns
    output: a dataframe with the count and precentage of nulls
    """
    df_nulls = df.isnull().sum()
    df_nulls = pd.DataFrame(np.c_[df_nulls, np.round(df_nulls/len(df) *100, 2)],
                                    columns=['count', 'percentage'], index = df_nulls.index)
    df_nulls.sort_values(by = df_nulls.columns[0], ascending=False, inplace = True)

    df_nulls = df_nulls.loc[[i for i in df_nulls.index if (df_nulls.loc[i, :] != 0).any() & (i not in ['SalePrice'])]]

    print('How many features had at least one null value?', len(df_nulls))
    print('{} most empty features of all:'.format(df_nulls.index[0]))
    return df_nulls[:n]

# %%
detect_nulls(df, n=40)

# %%
# fill the null values in PoolQC with None
df["PoolQC"] = df["PoolQC"].fillna("None")

# %%
# Write a for loop to fill the null values in
# 'MiscFeature', 'Fence', 'Alley', 'FireplaceQu'
# with None
for col in ('MiscFeature', 'Fence', 'Alley', 'FireplaceQu'):
    df[col] = df[col].fillna("None")

# %%
# some have to be filled with zero
# 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[col] = df[col].fillna(0)

# %%
# How to drop a column?
df.drop(columns=['PoolQC'], inplace=True)

# %%
# see the values in the Electrical column
df.Electrical.unique()

# %%
# drop the record with null in it
df.dropna(subset=['Electrical'], inplace=True)

# %%
# check and see if we have dropped it correctly
df.Electrical.isna().sum()

# %% [markdown]
# ### Your Turn

# %%
# see which columns have null?

# %%
# drop the record that doesn't have Released_Year

# %%
# inspect Meta_score

# %%
# fill it with the mean value

# %%
# see if we have any null values

# %% [markdown]
# ### Reference
#
# * Brandon Rhodes - Pandas From The Ground Up - PyCon 2015: [link](https://www.youtube.com/watch?v=5JnMutdy6Fw&list=PL2vN4d3B5vi5gCdw4I-RAJonYAhH7k8bp&ab_channel=PyCon2015)
# * Missing values – Mitra’s Kaggle Tutorial: [link](https://www.kaggle.com/code/mitramir5/missing-values-ordinal-data-and-stories)
# * Crash Course Statistics: [link](https://www.youtube.com/watch?v=zouPoc49xbk&list=PL8dPuuaLjXtNM_Y-bUAhblSAdWRnmBUcr&ab_channel=CrashCourse)
